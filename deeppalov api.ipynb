# %%
import requests

# %%
url = 'http://204.48.22.151:5555/model'
res = requests.post(url, json={"x": ["fuck off"]}).json()

# %%
res = requests.get('http://204.48.22.151:5555/api')

# %%
res.json()
# Out:
# ['x']

# %%
import torch

# %%
res = requests.post(url, json={"x": ["Ты лапочка"]}).json()
santiment = res[0][0]

# %% [markdown]
# ![image.png](attachment:image.png)
